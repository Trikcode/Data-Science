# %%
import requests
import pandas as pd

url = 'https://www.xeno-canto.org/api/2/recordings?query=cnt:uganda'
headers = {'content-type': 'application/json', 'Accept-Charset': 'UTF-8'}
response = requests.request("GET", url, headers=headers, data={})
jsondata = response.json()

recordings = jsondata['recordings']
df = pd.DataFrame(recordings)
df.to_csv('uganda.csv', index=False)

# %%
#webscrapp  html page
import requests
from bs4 import BeautifulSoup
import pandas as pd
url = 'https://keithgalli.github.io/web-scraping/webpage.html'
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')
# print(soup.prettify())
#load only web page not html
# url3 = 'https://jeffgeoff.com';
# page3 = requests.get(url3)
# soup3 = BeautifulSoup(page3.content, 'lxml')
# print(soup3.prettify())

# %%
table2 = soup.select('table.hockey-stats')[0]
columns = table2.select('thead th')
column_names = [c.string for c in columns]
print(column_names)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\hp\Desktop\MY NOTEBOOKS\NobertAyesigaDAY5.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hp/Desktop/MY%20NOTEBOOKS/NobertAyesigaDAY5.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> table2 = soup.select('table.hockey-stats')[0]
#       <a href='vscode-notebook-cell:/c%3A/Users/hp/Desktop/MY%20NOTEBOOKS/NobertAyesigaDAY5.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> columns = table2.select('thead th')
#       <a href='vscode-notebook-cell:/c%3A/Users/hp/Desktop/MY%20NOTEBOOKS/NobertAyesigaDAY5.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> column_names = [c.string for c in columns]
#
# IndexError: list index out of range

# %%
table_rows = table2.select('tbody tr')
l = []
for tr in table_rows:
    td = tr.find_all('td')
    # row = [tr.text for tr in td]
    row2 = [str(tr.get_text()).strip() for tr in td]
    l.append(row2)
df = pd.DataFrame(l, columns=column_names)
df.head()
# print(df)
# Out:
#          S                        Team    League  GP  G   A  TP PIM +/-     \
# 0  2014-15  MIT (Mass. Inst. of Tech.)   ACHA II  17  3   9  12  20      |
# 1  2015-16  MIT (Mass. Inst. of Tech.)   ACHA II   9  1   1   2   2      |
# 2  2016-17  MIT (Mass. Inst. of Tech.)   ACHA II  12  5   5  10   8   0  |
# 3  2017-18                Did not play                                   |
# 4  2018-19  MIT (Mass. Inst. of Tech.)  ACHA III   8  5  10  15   8      |
#
#   POST GP G A TP PIM +/-
# 0
# 1
# 2
# 3
# 4

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(2)

x = np.random.normal(3, 1, 100)
y = np.random.normal(150, 40, 100)
plt.scatter(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(19680801)

x = np.random.rand(10)
y = np.random.rand(10)
colors = np.random.rand(10)
area = (30 * np.random.rand(10))**2  # 0 to 15 point radii
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
train_x = x[:80]
train_y = y[:80]
test_x = x[:20]
test_y = y[:20]
# plt.scatter(train_x, train_y);
# plt.scatter(test_x, test_y);
plt.scatter(train_x, train_y, label='Training Data', color='b')
plt.show()

# %%
mymodel = np.poly1d(np.polyfit(train_x, train_y, 4))
myline = np.linspace(0, 6, 100)
plt.scatter(train_x, train_y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
# Draw a polynomial regression line through the data points
mymodel = np.poly1d(np.polyfit(train_x, train_y, 4))
myline = np.linspace(0, 6, 100)
plt.scatter(train_x, train_y)
plt.plot(myline, mymodel(myline))

# %%
import seaborn as sns

myData = pd.read_csv('heart.csv')
myData.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
myData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
myData.plot()
plt.show()

# %%
myData.nunique()
# Out:
# Age                50
# Sex                 2
# ChestPainType       4
# RestingBP          67
# Cholesterol       222
# FastingBS           2
# RestingECG          3
# MaxHR             119
# ExerciseAngina      2
# Oldpeak            53
# ST_Slope            3
# HeartDisease        2
# dtype: int64

# %%
from pyexpat import features
from random import shuffle
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=5, shuffle=True)
# shuffle to shuffle the data before splitting
shuffle(x)
shuffle(y)
#split the data into 80% training and 20% testing
x_train = x[:80]
x_test = x[80:]
y_train = y[:80]
y_test = y[80:]
print(x_train)
# print(x_test)
# Out:
# [3.50839624 2.66117803 2.92552924 3.73527958 1.75471191 2.73094304
#  1.81238771 2.1557863  2.8676711  2.34674973 3.56627544 3.61134078
#  3.52429643 2.36532069 0.34055054 4.35963386 3.04797059 2.92278133
#  3.20420798 3.69511961 3.50185721 3.06648901 2.61890748 3.32600343
#  4.04082395 2.96042976 4.58448706 3.82470301 2.12189211 2.90854738
#  3.77101174 4.73118467 1.57878277 1.56056097 2.01122095 2.9808695
#  2.78286473 3.38186623 3.84245628 1.88207455 2.53799465 2.76381597
#  4.21788563 3.00902525 2.17086471 2.8465048  1.94204778 4.46767801
#  4.00036589 1.13190935 2.61848352 1.14138761 3.25657045 2.15825263
#  1.2620405  2.25212905 4.40669624 2.59610773 3.04153939 2.81053074
#  3.1127265  3.00000976 3.35088849 3.54235257 3.50288142 2.09099239
#  0.95967695 3.04625552 3.08771022 2.32232442 3.37044454 3.53905832
#  2.94373317 5.23136679 4.17500122 1.20656441 5.29220801 4.36723542
#  3.21611601 2.6864918 ]
