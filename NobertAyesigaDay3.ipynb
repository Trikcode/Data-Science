# %%
import pandas as pd
#create dataset
data = {'Name': ['John', 'Anna', 'Peter', 'Linda'], "fruits": ['apple', 'banana', 'orange', 'pear'], "count": [1, 2, 3, 4]}
myvar = pd.DataFrame(data)
print(myvar)
# Out:
#     Name  fruits  count
# 0   John   apple      1
# 1   Anna  banana      2
# 2  Peter  orange      3
# 3  Linda    pear      4

# %%
df_excel = pd.read_excel("transactions.xlsx")
print(df_excel)
# Out:
#    transaction_id  product_id  price
# 0            1001           1    5.95
# 1            1002           2    6.95
# 2            1003           3    7.95

# %%
# get data from csv file
df_music = pd.read_csv("music.csv")
print(df_music)
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %%
myList = ['Tesla', 'BMW', 'Ford', 'Toyota']
myvar = pd.Series(myList)
print(myvar)
# Out:
# 0     Tesla
# 1       BMW
# 2      Ford
# 3    Toyota
# dtype: object

# %%
df = pd.read_csv("Admission_Predict.csv")
df.head(5)
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.tail(5)
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95

# %%
print(df['Chance of Admit '])
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 395    0.82
# 396    0.84
# 397    0.91
# 398    0.67
# 399    0.95
# Name: Chance of Admit , Length: 400, dtype: float64

# %%
#describe
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
#get more details
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
# shape of the data
df.shape
# Out:
# (400, 9)

# %%
# show if there is any null values
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
#how to drop null values
df.dropna(inplace=True)

# %%
null_data = pd.read_csv("C:/Users/hp/Desktop/datasetswithnullvalue.csv")
print(null_data)
# df.head(5)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
# show all the rows with null values
null_data[null_data.isnull().any(axis=1)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 17         45     90       112       NaN
# 27         60    103       132       NaN
# 91         45    107       137       NaN
# 118        60    105       125       NaN
# 141        60     97       127       NaN

# %%
# show all the columns with null values
# null_data[null_data.isnull().any(axis=0)]

# %%
#drop null values
print(null_data.dropna(inplace=True))
# Out:
# None

# %%
# drop specific columns
null_data.drop(['column1', 'column2'], axis=1, inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(df)
plt.show()

# %%
df.plot()
plt.show()

# %%
plt.scatter(df['GRE Score'], df['Chance of Admit '])
plt.show()

# %%
# plot histogram
df['GRE Score'].plot.hist()
# change the color of the histogram
df['GRE Score'].plot.hist(color='red')

plt.show()

# %%
df.plot(kind="scatter", x="CGPA", y="SOP")
# plt.show()
# Out:
# <AxesSubplot:xlabel='CGPA', ylabel='SOP'>

# %%
#access a column
df['GRE Score']
df.plot(kind="scatter", x="GRE Score", y="Chance of Admit ")
plt.show()

# %%
# query out a certain column and certain traits in that CGPA
df.query('CGPA > 8.5 ')
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 3             4        322          110                  3  3.5   2.5  8.67
# 5             6        330          115                  5  4.5   3.0  9.34
# 9            10        323          108                  3  3.5   3.0  8.60
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
#get content of one column
df['Chance of Admit '].head(5)
# Out:
# 0    0.92
# 1    0.76
# 2    0.72
# 3    0.80
# 4    0.65
# Name: Chance of Admit , dtype: float64

# %%
#get one row
df.iloc[0]
# Out:
# Serial No.             1.00
# GRE Score            337.00
# TOEFL Score          118.00
# University Rating      4.00
# SOP                    4.50
# LOR                    4.50
# CGPA                   9.65
# Research               1.00
# Chance of Admit        0.92
# Name: 0, dtype: float64

# %%
#get column CGPA
df['CGPA'].head(5)
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
#bar chart
df['CGPA'].value_counts().plot.bar()
plt.show()

# %%
#pie chart
df['CGPA'].value_counts().plot.pie()
#increase the size of the pie chart
df['CGPA'].value_counts().plot.pie(figsize=(10,10))
plt.show()

# %% [markdown]
# DAY 4

# %%
#column chart
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
#get total number of columns
len(df.columns)
# Out:
# 9

# %%
# show data types of each column
df.dtypes
# Out:
# Serial No.             int64
# GRE Score              int64
# TOEFL Score            int64
# University Rating      int64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# dtype: object

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot=True, linewidths=0.5, fmt='.1f', cmap='rainbow')
plt.show()

# %%
# get the correlation between the columns
df.corr()
# Out:
#                    Serial No.  GRE Score  TOEFL Score  University Rating  \
# Serial No.           1.000000  -0.097526    -0.147932          -0.169948
# GRE Score           -0.097526   1.000000     0.835977           0.668976
# TOEFL Score         -0.147932   0.835977     1.000000           0.695590
# University Rating   -0.169948   0.668976     0.695590           1.000000
# SOP                 -0.166932   0.612831     0.657981           0.734523
# LOR                 -0.088221   0.557555     0.567721           0.660123
# CGPA                -0.045608   0.833060     0.828417           0.746479
# Research            -0.063138   0.580391     0.489858           0.447783
# Chance of Admit      0.042336   0.802610     0.791594           0.711250
#
#                         SOP      LOR       CGPA  Research  Chance of Admit
# Serial No.        -0.166932 -0.088221 -0.045608 -0.063138          0.042336
# GRE Score          0.612831  0.557555  0.833060  0.580391          0.802610
# ...

# %%
#plot a pie chart using university rating
colors = ['red', 'blue', 'green', 'yellow', 'orange']
explode = [0, 0.1, 0, 0, 0]
plt.pie(df['University Rating'].value_counts(), labels=df['University Rating'].value_counts().index, colors=colors, explode=explode, autopct='%1.1f%%')
plt.show()
